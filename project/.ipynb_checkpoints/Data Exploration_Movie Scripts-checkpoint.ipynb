# %% [markdown]
# # Diversity in the film industry: data exploration - Movie scripts

# %% [markdown]
# ## 1. Importing libraries and dataset

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# %%
film_gender = round(pd.read_csv('./data/script/film_gender_clean.csv', index_col=0), 2)
year_gender = round(pd.read_csv('./data/script/year_gender_clean.csv', index_col=0), 2)
total_gender = round(pd.read_csv('./data/script/total_gender_clean.csv', index_col=0), 2)

film_race = round(pd.read_csv('./data/script/film_race_clean.csv', index_col=0), 2)
year_race = round(pd.read_csv('./data/script/year_race_clean.csv', index_col=0), 2)
total_race = round(pd.read_csv('./data/script/total_race_clean.csv', index_col=0), 2)

script = pd.read_csv('./data/actor-metrics.csv')
script.drop('imdb', axis=1, inplace=True)

# %% [markdown]
# ## 2. Exploring gender

# %% [markdown]
# ### 2.1. Totals

# %%
total_gender
# Out:
#    gender     words  sentences  total_words  total_sentences  words_perc  \
# 0  female   51119.0     8114.0     172653.0          26351.0       29.61
# 1    male  121534.0    18237.0     172653.0          26351.0       70.39
#
#    sentences_perc  cast_perc_gender
# 0           30.79              31.7
# 1           69.21              68.3

# %% [markdown]
# ### 2.2. Analyzing by film

# %%
# movies with highest % of female cast
film_gender.loc[film_gender.gender=='female'].sort_values('cast_perc_gender', ascending=False)
# Out:
#     year                                      film  gender  words  sentences  \
# 14  2015                                   Mad Max  female   2316        505
# 12  2015                                  Brooklyn  female   7427       1077
# 32  2017                                 Lady Bird  female   5949        899
# 25  2017                      Call me by your name  female   1383        226
# 4   1989                        Driving Miss Daisy  female   4143        674
# 16  2015                                      Room  female   5243        868
# 34  2017                            Phantom Thread  female   2743        372
# 40  2017  Three Billboards Outside Ebbing Missouri  female   3403        444
# 6   1989                           Field of Dreams  female   1848        285
# 30  2017                                   Get Out  female   2039        425
# 8   1989                              My Left Foot  female   2158        439
# 36  2017                                  The Post  female   3972        551
# 22  2015                               The Martian  female   2488        419
# 20  2015                             The Big Short  female   1294        176
# 27  2017                              Darkest Hour  female    869        133
# 38  2017                        The Shape of Water  female   1470        227
# 0   1989                Born on the Fourth of July  female    536         75
# 2   1989                        Dead Poets Society  female    221         69
# 18  2015                                 Spotlight  female   1338        209
# 10  2015                           Bridge of Spies  female    279         41
# 24  2015                              The revenant  female      0          0
# 29  2017                                   Dunkirk  female      0          0
#
#     total_words  total_sentences  words_perc  sentences_perc  cast_perc_gender
# 14         3130              694       73.99           72.77             75.00
# 12        10591             1469       70.13           73.32             72.22
# 32         7664             1148       77.62           78.31             58.33
# 25         6673             1048       20.73           21.56             50.00
# 4          9675             1520       42.82           44.34             50.00
# 16         8373             1414       62.62           61.39             50.00
# 34         5541              783       49.50           47.51             50.00
# 40         9480             1195       35.90           37.15             38.89
# 6          8933             1299       20.69           21.94             37.50
# 30         7094             1330       28.74           31.95             36.36
# 8          4749              980       45.44           44.80             33.33
# 36        11135             1528       35.67           36.06             31.25
# 22        10550             1507       23.58           27.80             28.57
# 20        13241             1782        9.77            9.88             26.09
# 27         8034             1077       10.82           12.35             18.18
# 38         8036             1347       18.29           16.85             18.18
# 0          5151              620       10.41           12.10             13.33
# 2          5217             1289        4.24            5.35              9.09
# 18        13113             1975       10.20           10.58              6.67
# 10         9915             1351        2.81            3.03              5.88
# 24         4005              549        0.00            0.00              0.00
# 29         2353              446        0.00            0.00              0.00

# %%
# movies with highest % of female sentences
film_gender.loc[film_gender.gender=='female'].sort_values('sentences_perc', ascending=False)
# Out:
#     year                                      film  gender  words  sentences  \
# 32  2017                                 Lady Bird  female   5949        899
# 12  2015                                  Brooklyn  female   7427       1077
# 14  2015                                   Mad Max  female   2316        505
# 16  2015                                      Room  female   5243        868
# 34  2017                            Phantom Thread  female   2743        372
# 8   1989                              My Left Foot  female   2158        439
# 4   1989                        Driving Miss Daisy  female   4143        674
# 40  2017  Three Billboards Outside Ebbing Missouri  female   3403        444
# 36  2017                                  The Post  female   3972        551
# 30  2017                                   Get Out  female   2039        425
# 22  2015                               The Martian  female   2488        419
# 6   1989                           Field of Dreams  female   1848        285
# 25  2017                      Call me by your name  female   1383        226
# 38  2017                        The Shape of Water  female   1470        227
# 27  2017                              Darkest Hour  female    869        133
# 0   1989                Born on the Fourth of July  female    536         75
# 18  2015                                 Spotlight  female   1338        209
# 20  2015                             The Big Short  female   1294        176
# 2   1989                        Dead Poets Society  female    221         69
# 10  2015                           Bridge of Spies  female    279         41
# 24  2015                              The revenant  female      0          0
# 29  2017                                   Dunkirk  female      0          0
#
#     total_words  total_sentences  words_perc  sentences_perc  cast_perc_gender
# 32         7664             1148       77.62           78.31             58.33
# 12        10591             1469       70.13           73.32             72.22
# 14         3130              694       73.99           72.77             75.00
# 16         8373             1414       62.62           61.39             50.00
# 34         5541              783       49.50           47.51             50.00
# 8          4749              980       45.44           44.80             33.33
# 4          9675             1520       42.82           44.34             50.00
# 40         9480             1195       35.90           37.15             38.89
# 36        11135             1528       35.67           36.06             31.25
# 30         7094             1330       28.74           31.95             36.36
# 22        10550             1507       23.58           27.80             28.57
# 6          8933             1299       20.69           21.94             37.50
# 25         6673             1048       20.73           21.56             50.00
# 38         8036             1347       18.29           16.85             18.18
# 27         8034             1077       10.82           12.35             18.18
# 0          5151              620       10.41           12.10             13.33
# 18        13113             1975       10.20           10.58              6.67
# 20        13241             1782        9.77            9.88             26.09
# 2          5217             1289        4.24            5.35              9.09
# 10         9915             1351        2.81            3.03              5.88
# 24         4005              549        0.00            0.00              0.00
# 29         2353              446        0.00            0.00              0.00

# %%
# movies with highest % of female words
film_gender.loc[film_gender.gender=='female'].sort_values('words_perc', ascending=False).head()
# Out:
#     year            film  gender  words  sentences  total_words  \
# 32  2017       Lady Bird  female   5949        899         7664
# 14  2015         Mad Max  female   2316        505         3130
# 12  2015        Brooklyn  female   7427       1077        10591
# 16  2015            Room  female   5243        868         8373
# 34  2017  Phantom Thread  female   2743        372         5541
#
#     total_sentences  words_perc  sentences_perc  cast_perc_gender
# 32             1148       77.62           78.31             58.33
# 14              694       73.99           72.77             75.00
# 12             1469       70.13           73.32             72.22
# 16             1414       62.62           61.39             50.00
# 34              783       49.50           47.51             50.00

# %% [markdown]
# ### 2.3. Analyzing by year

# %%
# years with highest % of female cast
year_gender.loc[year_gender.gender=='female'].sort_values('cast_perc_gender', ascending=False).head()
# Out:
#    year  gender    words  sentences  total_words  total_sentences  words_perc  \
# 2  2015  female  20385.0     3295.0      72918.0          10741.0       27.96
# 4  2017  female  21828.0     3277.0      66010.0           9902.0       33.07
# 0  1989  female   8906.0     1542.0      33725.0           5708.0       26.41
#
#    sentences_perc  cast_perc_gender
# 2           30.68             34.19
# 4           33.09             32.32
# 0           27.01             24.49

# %%
# years with highest % of female sentences
year_gender.loc[year_gender.gender=='female'].sort_values('sentences_perc', ascending=False).head()
# Out:
#    year  gender    words  sentences  total_words  total_sentences  words_perc  \
# 4  2017  female  21828.0     3277.0      66010.0           9902.0       33.07
# 2  2015  female  20385.0     3295.0      72918.0          10741.0       27.96
# 0  1989  female   8906.0     1542.0      33725.0           5708.0       26.41
#
#    sentences_perc  cast_perc_gender
# 4           33.09             32.32
# 2           30.68             34.19
# 0           27.01             24.49

# %%
# years with highest % of female words
year_gender.loc[year_gender.gender=='female'].sort_values('words_perc', ascending=False).head()
# Out:
#    year  gender    words  sentences  total_words  total_sentences  words_perc  \
# 4  2017  female  21828.0     3277.0      66010.0           9902.0       33.07
# 2  2015  female  20385.0     3295.0      72918.0          10741.0       27.96
# 0  1989  female   8906.0     1542.0      33725.0           5708.0       26.41
#
#    sentences_perc  cast_perc_gender
# 4           33.09             32.32
# 2           30.68             34.19
# 0           27.01             24.49

# %% [markdown]
# ## 3. Exploring race

# %% [markdown]
# ### 3.1. Totals

# %%
total_race
# Out:
#   race_simple     words  sentences  total_words  total_sentences  words_perc  \
# 0         POC   15172.0     2377.0     172653.0          26351.0        8.79
# 1       White  157481.0    23974.0     172653.0          26351.0       91.21
#
#    sentences_perc  cast_perc_race
# 0            9.02           11.32
# 1           90.98           88.68

# %% [markdown]
# ### 3.2. Analyzing by film

# %%
# movies with highest % of POC cast
film_race.loc[film_race.race_simple=='POC'].sort_values('cast_perc_race', ascending=False)
# Out:
#     year                                      film race_simple  words  \
# 24  2017                                   Get Out         POC   3309
# 17  2015                               The Martian         POC   2589
# 3   1989                        Driving Miss Daisy         POC   3531
# 12  2015                                      Room         POC    616
# 10  2015                                   Mad Max         POC    320
# 26  2017                                 Lady Bird         POC    292
# 33  2017  Three Billboards Outside Ebbing Missouri         POC    782
# 15  2015                             The Big Short         POC    515
# 5   1989                           Field of Dreams         POC   1369
# 21  2017                              Darkest Hour         POC    147
# 31  2017                        The Shape of Water         POC   1319
# 0   1989                Born on the Fourth of July         POC    208
# 29  2017                                  The Post         POC    175
# 9   2015                                  Brooklyn         POC      0
# 8   2015                           Bridge of Spies         POC      0
# 14  2015                                 Spotlight         POC      0
# 2   1989                        Dead Poets Society         POC      0
# 19  2015                              The revenant         POC      0
# 20  2017                      Call me by your name         POC      0
# 23  2017                                   Dunkirk         POC      0
# 7   1989                              My Left Foot         POC      0
# 28  2017                            Phantom Thread         POC      0
#
#     sentences  total_words  total_sentences  words_perc  sentences_perc  \
# 24        653         7094             1330       46.65           49.10
# 17        365        10550             1507       24.54           24.22
# 3         544         9675             1520       36.50           35.79
# 12         92         8373             1414        7.36            6.51
# 10         64         3130              694       10.22            9.22
# 26         49         7664             1148        3.81            4.27
# 33         76         9480             1195        8.25            6.36
# 15         71        13241             1782        3.89            3.98
# 5         207         8933             1299       15.33           15.94
# 21         27         8034             1077        1.83            2.51
# 31        201         8036             1347       16.41           14.92
# 0          15         5151              620        4.04            2.42
# 29         13        11135             1528        1.57            0.85
# 9           0        10591             1469        0.00            0.00
# 8           0         9915             1351        0.00            0.00
# 14          0        13113             1975        0.00            0.00
# 2           0         5217             1289        0.00            0.00
# 19          0         4005              549        0.00            0.00
# 20          0         6673             1048        0.00            0.00
# 23          0         2353              446        0.00            0.00
# 7           0         4749              980        0.00            0.00
# 28          0            0              783        0.00            0.00
#
#     cast_perc_race
# 24           45.45
# 17           35.71
# 3            33.33
# 12           25.00
# 10           16.67
# 26           16.67
# 33           16.67
# 15           13.04
# 5            12.50
# 21            9.09
# 31            9.09
# 0             6.67
# 29            6.25
# 9             0.00
# 8             0.00
# 14            0.00
# 2             0.00
# 19            0.00
# 20            0.00
# 23            0.00
# 7             0.00
# 28            0.00

# %%
# movies with highest % of POC sentences
film_race.loc[film_race.race_simple=='POC'].sort_values('sentences_perc', ascending=False).head()
# Out:
#     year                film race_simple  words  sentences  total_words  \
# 24  2017             Get Out         POC   3309        653         7094
# 3   1989  Driving Miss Daisy         POC   3531        544         9675
# 17  2015         The Martian         POC   2589        365        10550
# 5   1989     Field of Dreams         POC   1369        207         8933
# 31  2017  The Shape of Water         POC   1319        201         8036
#
#     total_sentences  words_perc  sentences_perc  cast_perc_race
# 24             1330       46.65           49.10           45.45
# 3              1520       36.50           35.79           33.33
# 17             1507       24.54           24.22           35.71
# 5              1299       15.33           15.94           12.50
# 31             1347       16.41           14.92            9.09

# %%
# movies with highest % of POC words
film_race.loc[film_race.race_simple=='POC'].sort_values('words_perc', ascending=False).head()
# Out:
#     year                film race_simple  words  sentences  total_words  \
# 24  2017             Get Out         POC   3309        653         7094
# 3   1989  Driving Miss Daisy         POC   3531        544         9675
# 17  2015         The Martian         POC   2589        365        10550
# 31  2017  The Shape of Water         POC   1319        201         8036
# 5   1989     Field of Dreams         POC   1369        207         8933
#
#     total_sentences  words_perc  sentences_perc  cast_perc_race
# 24             1330       46.65           49.10           45.45
# 3              1520       36.50           35.79           33.33
# 17             1507       24.54           24.22           35.71
# 31             1347       16.41           14.92            9.09
# 5              1299       15.33           15.94           12.50

# %% [markdown]
# ### 3.3. Analyzing by year

# %%
# movies with highest % of POC cast
year_race.loc[year_race.race_simple=='POC'].sort_values('cast_perc_race', ascending=False).head()
# Out:
#    year race_simple   words  sentences  total_words  total_sentences  \
# 4  2017         POC  6024.0     1019.0      66010.0           9902.0
# 2  2015         POC  4040.0      592.0      72918.0          10741.0
# 0  1989         POC  5108.0      766.0      33725.0           5708.0
#
#    words_perc  sentences_perc  cast_perc_race
# 4        9.13           10.29           13.13
# 2        5.54            5.51           11.11
# 0       15.15           13.42            8.16

# %%
# movies with highest % of POC sentences
year_race.loc[year_race.race_simple=='POC'].sort_values('sentences_perc', ascending=False).head()
# Out:
#    year race_simple   words  sentences  total_words  total_sentences  \
# 0  1989         POC  5108.0      766.0      33725.0           5708.0
# 4  2017         POC  6024.0     1019.0      66010.0           9902.0
# 2  2015         POC  4040.0      592.0      72918.0          10741.0
#
#    words_perc  sentences_perc  cast_perc_race
# 0       15.15           13.42            8.16
# 4        9.13           10.29           13.13
# 2        5.54            5.51           11.11

# %%
# movies with highest % of POC words
year_race.loc[year_race.race_simple=='POC'].sort_values('words_perc', ascending=False).head()
# Out:
#    year race_simple   words  sentences  total_words  total_sentences  \
# 0  1989         POC  5108.0      766.0      33725.0           5708.0
# 4  2017         POC  6024.0     1019.0      66010.0           9902.0
# 2  2015         POC  4040.0      592.0      72918.0          10741.0
#
#    words_perc  sentences_perc  cast_perc_race
# 0       15.15           13.42            8.16
# 4        9.13           10.29           13.13
# 2        5.54            5.51           11.11

# %% [markdown]
# ## 4. Looking into female POC

# %%
# creating dataframe filtering 'script' by female and POC
film_female_POC = script.loc[(script.race_simple=='POC')&(script.gender=='female')][['year', 'film', 'sentences']].groupby(['year','film'], as_index=False).sum()    
film_female_POC
# Out:
#    year                                      film  sentences
# 0  1989                        driving-miss-daisy       34.0
# 1  2015                                   mad-max       64.0
# 2  2015                                      room       63.0
# 3  2015                             the-big-short       51.0
# 4  2017                                   get-out       48.0
# 5  2017                                 lady-bird       20.0
# 6  2017                                  the-post       13.0
# 7  2017                        the-shape-of-water      201.0
# 8  2017  three-billboards-outside-ebbing-missouri       11.0

# %%
# getting count of total sentences by movie
film_sentences = dict(script.groupby('film').sentences.sum())
film_sentences
# Out:
# {'born-on-the-fourth-of-july': 620.0,
#  'bridge-of-spies': 1351.0,
#  'brooklyn': 1469.0,
#  'call-me-by-your-name': 1048.0,
#  'darkest-hour': 1077.0,
#  'dead-poets-society': 1289.0,
#  'driving-miss-daisy': 1520.0,
#  'dunkirk': 446.0,
#  'field-of-dreams': 1299.0,
#  'get-out': 1330.0,
#  'lady-bird': 1148.0,
#  'mad-max': 694.0,
#  'my-left-foot': 980.0,
#  'phantom-thread': 783.0,
#  'room': 1414.0,
#  'spotlight': 1975.0,
#  'the-big-short': 1782.0,
#  'the-martian': 1507.0,
#  'the-post': 1528.0,
#  'the-revenant': 549.0,
#  'the-shape-of-water': 1347.0,
#  'three-billboards-outside-ebbing-missouri': 1195.0}

# %%
# appending number of sentences to dataframe
film_female_POC['total_sentences'] = film_female_POC.film.map(film_sentences)

# adding new column with % of female POC sentences out of total sentences
film_female_POC['female_POC_perc'] = film_female_POC['sentences']/film_female_POC['total_sentences']*100

# %%
# getting dataframe with all movies and number of total sentences
script = script.groupby(['year','film'], as_index=False).sentences.sum()

# %%
# merging with 'script' to keep movies with 0% sentences by female POC
film_female_POC = pd.merge(script, film_female_POC, how='left', on=['film', 'year'])

# removing unwanted columns
film_female_POC = film_female_POC[['year', 'film', 'female_POC_perc']].groupby('film', as_index=False).sum()

# %%
# exporting dataset
film_female_POC.to_csv('./data/script/film_female_POC.csv')

# %%
# percentage of female POC sentences by movie 
film_female_POC
# Out:
#                                         film  year  female_POC_perc
# 0                 born-on-the-fourth-of-july  1989         0.000000
# 1                            bridge-of-spies  2015         0.000000
# 2                                   brooklyn  2015         0.000000
# 3                       call-me-by-your-name  2017         0.000000
# 4                               darkest-hour  2017         0.000000
# 5                         dead-poets-society  1989         0.000000
# 6                         driving-miss-daisy  1989         2.236842
# 7                                    dunkirk  2017         0.000000
# 8                            field-of-dreams  1989         0.000000
# 9                                    get-out  2017         3.609023
# 10                                 lady-bird  2017         1.742160
# 11                                   mad-max  2015         9.221902
# 12                              my-left-foot  1989         0.000000
# 13                            phantom-thread  2017         0.000000
# 14                                      room  2015         4.455446
# 15                                 spotlight  2015         0.000000
# 16                             the-big-short  2015         2.861953
# 17                               the-martian  2015         0.000000
# 18                                  the-post  2017         0.850785
# 19                              the-revenant  2015         0.000000
# 20                        the-shape-of-water  2017        14.922049
# 21  three-billboards-outside-ebbing-missouri  2017         0.920502
